# %% [markdown]
# # Sales Prediction Project
# # Author: Udit Gupta
# # Goal: Predict Store Sales using Machine Learning

# %%
# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in c:\users\asus\appdata\local\programs\python\python39\lib\site-packages (2.1.4)
# Requirement already satisfied: numpy in c:\users\asus\appdata\local\programs\python\python39\lib\site-packages (from xgboost) (2.0.2)
# Requirement already satisfied: scipy in c:\users\asus\appdata\local\programs\python\python39\lib\site-packages (from xgboost) (1.13.1)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, r2_score
from xgboost import XGBRegressor

# %%
df=pd.read_csv('train.csv')
store=pd.read_csv('store.csv')
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18468\1981409130.py:1: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('train.csv')

# %%
df.head()
# Out:
#    Store  DayOfWeek        Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5  2015-07-31   5263        555     1      1            0
# 1      2          5  2015-07-31   6064        625     1      1            0
# 2      3          5  2015-07-31   8314        821     1      1            0
# 3      4          5  2015-07-31  13995       1498     1      1            0
# 4      5          5  2015-07-31   4822        559     1      1            0
#
#    SchoolHoliday
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1

# %%
store.head()
# Out:
#    Store StoreType Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0      1         c          a               1270.0                        9.0
# 1      2         a          a                570.0                       11.0
# 2      3         a          a              14130.0                       12.0
# 3      4         c          c                620.0                        9.0
# 4      5         a          a              29910.0                        4.0
#
#    CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 0                    2008.0       0              NaN              NaN
# 1                    2007.0       1             13.0           2010.0
# 2                    2006.0       1             14.0           2011.0
# 3                    2009.0       0              NaN              NaN
# 4                    2015.0       0              NaN              NaN
#
#      PromoInterval
# 0              NaN
# 1  Jan,Apr,Jul,Oct
# 2  Jan,Apr,Jul,Oct
# 3              NaN
# 4              NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1017209 entries, 0 to 1017208
# Data columns (total 9 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   Store          1017209 non-null  int64
#  1   DayOfWeek      1017209 non-null  int64
#  2   Date           1017209 non-null  object
#  3   Sales          1017209 non-null  int64
#  4   Customers      1017209 non-null  int64
#  5   Open           1017209 non-null  int64
#  6   Promo          1017209 non-null  int64
#  7   StateHoliday   1017209 non-null  object
#  8   SchoolHoliday  1017209 non-null  int64
# dtypes: int64(7), object(2)
# memory usage: 69.8+ MB

# %%
df.describe()
# Out:
#               Store     DayOfWeek         Sales     Customers          Open  \
# count  1.017209e+06  1.017209e+06  1.017209e+06  1.017209e+06  1.017209e+06
# mean   5.584297e+02  3.998341e+00  5.773819e+03  6.331459e+02  8.301067e-01
# std    3.219087e+02  1.997391e+00  3.849926e+03  4.644117e+02  3.755392e-01
# min    1.000000e+00  1.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    2.800000e+02  2.000000e+00  3.727000e+03  4.050000e+02  1.000000e+00
# 50%    5.580000e+02  4.000000e+00  5.744000e+03  6.090000e+02  1.000000e+00
# 75%    8.380000e+02  6.000000e+00  7.856000e+03  8.370000e+02  1.000000e+00
# max    1.115000e+03  7.000000e+00  4.155100e+04  7.388000e+03  1.000000e+00
#
#               Promo  SchoolHoliday
# count  1.017209e+06   1.017209e+06
# mean   3.815145e-01   1.786467e-01
# std    4.857586e-01   3.830564e-01
# min    0.000000e+00   0.000000e+00
# 25%    0.000000e+00   0.000000e+00
# 50%    0.000000e+00   0.000000e+00
# 75%    1.000000e+00   0.000000e+00
# max    1.000000e+00   1.000000e+00

# %%
df=df.merge(store,on='Store',how='left')


df
# Out:
#          Store  DayOfWeek        Date  Sales  Customers  Open  Promo  \
# 0            1          5  2015-07-31   5263        555     1      1
# 1            2          5  2015-07-31   6064        625     1      1
# 2            3          5  2015-07-31   8314        821     1      1
# 3            4          5  2015-07-31  13995       1498     1      1
# 4            5          5  2015-07-31   4822        559     1      1
# ...        ...        ...         ...    ...        ...   ...    ...
# 1017204   1111          2  2013-01-01      0          0     0      0
# 1017205   1112          2  2013-01-01      0          0     0      0
# 1017206   1113          2  2013-01-01      0          0     0      0
# 1017207   1114          2  2013-01-01      0          0     0      0
# 1017208   1115          2  2013-01-01      0          0     0      0
#
#         StateHoliday  SchoolHoliday StoreType Assortment  CompetitionDistance  \
# 0                  0              1         c          a               1270.0
# 1                  0              1         a          a                570.0
# 2                  0              1         a          a              14130.0
# 3                  0              1         c          c                620.0
# 4                  0              1         a          a              29910.0
# ...              ...            ...       ...        ...                  ...
# 1017204            a              1         a          a               1900.0
# 1017205            a              1         c          c               1880.0
# 1017206            a              1         a          c               9260.0
# 1017207            a              1         a          c                870.0
# 1017208            a              1         d          c               5350.0
#
#          CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 0                              9.0                    2008.0       0
# 1                             11.0                    2007.0       1
# 2                             12.0                    2006.0       1
# 3                              9.0                    2009.0       0
# 4                              4.0                    2015.0       0
# ...                            ...                       ...     ...
# 1017204                        6.0                    2014.0       1
# 1017205                        4.0                    2006.0       0
# 1017206                        NaN                       NaN       0
# 1017207                        NaN                       NaN       0
# 1017208                        NaN                       NaN       1
#
#          Promo2SinceWeek  Promo2SinceYear     PromoInterval
# 0                    NaN              NaN               NaN
# 1                   13.0           2010.0   Jan,Apr,Jul,Oct
# 2                   14.0           2011.0   Jan,Apr,Jul,Oct
# 3                    NaN              NaN               NaN
# 4                    NaN              NaN               NaN
# ...                  ...              ...               ...
# 1017204             31.0           2013.0   Jan,Apr,Jul,Oct
# 1017205              NaN              NaN               NaN
# 1017206              NaN              NaN               NaN
# 1017207              NaN              NaN               NaN
# 1017208             22.0           2012.0  Mar,Jun,Sept,Dec
#
# [1017209 rows x 18 columns]

# %%
# Total missing values in cols
df.isnull().sum()
# Out:
# Store                             0
# DayOfWeek                         0
# Date                              0
# Sales                             0
# Customers                         0
# Open                              0
# Promo                             0
# StateHoliday                      0
# SchoolHoliday                     0
# StoreType                         0
# Assortment                        0
# CompetitionDistance            2642
# CompetitionOpenSinceMonth    323348
# CompetitionOpenSinceYear     323348
# Promo2                            0
# Promo2SinceWeek              508031
# Promo2SinceYear              508031
# PromoInterval                508031
# dtype: int64

# %%
# Handling missing values
df.fillna(0,inplace=True)

# %%
# Total missing values in cols
df.isnull().sum()
# Out:
# Store                        0
# DayOfWeek                    0
# Date                         0
# Sales                        0
# Customers                    0
# Open                         0
# Promo                        0
# StateHoliday                 0
# SchoolHoliday                0
# StoreType                    0
# Assortment                   0
# CompetitionDistance          0
# CompetitionOpenSinceMonth    0
# CompetitionOpenSinceYear     0
# Promo2                       0
# Promo2SinceWeek              0
# Promo2SinceYear              0
# PromoInterval                0
# dtype: int64

# %%
# Now Apply Feature Enginnering
df['Date']=pd.to_datetime(df['Date'])
df['Year']=df['Date'].dt.year
df['Month']=df['Date'].dt.month
df['Day']=df['Date'].dt.day
df['Week']=df['Date'].dt.isocalendar().week

# %%
# remove closed stores
df=df[df['Open']==1]

# %%
# For previous day sale we use lag faeture
df=df.sort_values(['Store','Date'])
df['Lag_1']=df.groupby('Store')['Sales'].shift(1)
df.dropna(inplace=True)

# %%
df = pd.get_dummies(df, drop_first=True)

# %%
# Encode catgeorical data
df=pd.get_dummies(df,drop_first=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 841047 entries, 1011635 to 1114
# Data columns (total 31 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Store                           841047 non-null  int64
#  1   DayOfWeek                       841047 non-null  int64
#  2   Date                            841047 non-null  datetime64[ns]
#  3   Sales                           841047 non-null  int64
#  4   Customers                       841047 non-null  int64
#  5   Open                            841047 non-null  int64
#  6   Promo                           841047 non-null  int64
#  7   SchoolHoliday                   841047 non-null  int64
#  8   CompetitionDistance             841047 non-null  float64
#  9   CompetitionOpenSinceMonth       841047 non-null  float64
#  10  CompetitionOpenSinceYear        841047 non-null  float64
#  11  Promo2                          841047 non-null  int64
#  12  Promo2SinceWeek                 841047 non-null  float64
#  13  Promo2SinceYear                 841047 non-null  float64
#  14  Year                            841047 non-null  int32
#  15  Month                           841047 non-null  int32
#  16  Day                             841047 non-null  int32
#  17  Week                            841047 non-null  UInt32
#  18  Lag_1                           841047 non-null  float64
#  19  StateHoliday_0                  841047 non-null  bool
#  20  StateHoliday_a                  841047 non-null  bool
#  21  StateHoliday_b                  841047 non-null  bool
#  22  StateHoliday_c                  841047 non-null  bool
#  23  StoreType_b                     841047 non-null  bool
#  24  StoreType_c                     841047 non-null  bool
#  25  StoreType_d                     841047 non-null  bool
#  26  Assortment_b                    841047 non-null  bool
#  27  Assortment_c                    841047 non-null  bool
#  28  PromoInterval_Feb,May,Aug,Nov   841047 non-null  bool
#  29  PromoInterval_Jan,Apr,Jul,Oct   841047 non-null  bool
#  30  PromoInterval_Mar,Jun,Sept,Dec  841047 non-null  bool
# dtypes: UInt32(1), bool(12), datetime64[ns](1), float64(6), int32(3), int64(8)
# memory usage: 125.9 MB

# %%
# Train Test split
# it is time series data we can't randomly split
# if split it randomly then if 2016 will be at train and 2014 at test 
# first past year come after that future
train=df[df['Year']<2015]
test=df[df['Year']>=2015]

X_train=train.drop(['Sales','Date'],axis=1)
y_train=train['Sales']

X_test=test.drop(['Sales','Date'],axis=1)
y_test=test['Sales']

# %%
X_train.shape
# Out:
# (645015, 29)

# %%
X_test.shape
# Out:
# (196032, 29)

# %%
#Model Training (XGBoost)
from xgboost import XGBRegressor

model=XGBRegressor(
    n_estimators=300,
    learning_rate=0.05,
    max_depth=6,
    random_state=42
)
model.fit(X_train,y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.05, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=6, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=300, n_jobs=None,
#              num_parallel_tree=None, random_state=42, ...)

# %%
# Pediction
pred=model.predict(X_test)

# %%
# Model Evaluation

from sklearn.metrics import mean_absolute_error,r2_score

print("MAE",mean_absolute_error(y_test,pred))
print("R2 Score:",r2_score(y_test,pred))
# Out:
# MAE 510.4378967285156
# R2 Score: 0.9444167613983154

# %%
plt.figure(figsize=(8,6))
plt.scatter(y_test,pred,alpha=0.3)
plt.xlabel("Actual Sales")
plt.ylabel("Prediction sales")
plt.title("Actual vs Prediction Sales")
plt.show()

# %%
importances=model.feature_importances_

plt.figure(figsize=(12,6))
plt.bar(X_train.columns,importances)
plt.xticks(rotation=90)
plt.title("Feature Importance")
plt.show()

# %%
# Lag_7 (Last week sale)
df['Lag_7']=df.groupby('Store')['Sales'].shift(7)

# %%
# Rolling Mean (Last 7 days average)
df['Rolling_Mean_7']=df.groupby('Store')['Sales'].shift(1).rolling(7).mean()

# %%
# Hyperparameter Tuning
from sklearn.model_selection import GridSearchCV

params={
    'max_depth':[4,6,8],
    'learning_rate':[0.01,0.05,0.1],
    'n_estimators':[200,300]
}
grid=GridSearchCV(XGBRegressor(),params,cv=3)
grid.fit(X_train,y_train)

print(grid.best_params_)
# Out:
# {'learning_rate': 0.05, 'max_depth': 4, 'n_estimators': 200}

# %%
import pickle
pickle.dump(model, open("final_sales_model.pkl", "wb"))

# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'final_sales_model.pkl',
#  'store.csv',
#  'train.csv',
#  'Untitled.ipynb']

# %%
import pickle

loaded_model = pickle.load(open("final_sales_model.pkl", "rb"))

# %%
prediction = loaded_model.predict(X_test)

# %%
from sklearn.metrics import r2_score

print("R2 after loading:", r2_score(y_test, prediction))
# Out:
# R2 after loading: 0.9444167613983154

# %%
# first row of test dataset
sample_input = X_test.iloc[0:1]
# Out:
# array([5319.1914], dtype=float32)

# %%
# the row provided to model and it provide output sale of that row
loaded_model.predict(sample_input)
# Out:
# array([5319.1914], dtype=float32)

# %%
pred_value = loaded_model.predict(sample_input)[0]

print("Actual:", y_test.iloc[0])
print("Predicted:", pred_value)
# Out:
# Actual: 5509
# Predicted: 5319.1914
